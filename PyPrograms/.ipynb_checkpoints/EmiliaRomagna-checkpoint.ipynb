# %%
import numpy as np
import pandas as pd
import os, sys
import codecs
import utm
from pyproj import Proj, transform
from scipy.io import savemat

# %%
cwd = os.getcwd()

# %%
directory_name = "/FormattedEmilia"
original_file_type = ".xlsx"
whole_table = pd.DataFrame()
#change last part depending on imported file type
for files in os.listdir(cwd + directory_name):
    if files.endswith(original_file_type):
        
        file_path = cwd + directory_name + "/" + files
        
        df = pd.read_excel(file_path)
    
        arr = []
        for i in range(len(df['Piezometria (m)'])):
            if type(df['Piezometria (m)'].values[i]) == str:
                arr = np.append(arr, i)

        for j in arr:
            df = df[df.index != j]
            
        whole_table = whole_table.append(df)
        
        xls = pd.ExcelFile(cwd + directory_name + "/Anagrafica/dati_monitoraggio_acque_sotterranee_2010-2012.xlsx")
        
df = pd.read_excel(xls, 'Piezometria_Soggiacenza')

df = df[['Codice', 'Data', 'Piezometria (m)', 'Soggiacenza (m)']]

whole_table = whole_table[['Codice', 'Data', 'Piezometria (m)', 'Soggiacenza (m)']]
        
whole_table = whole_table.append(df)

whole_table
# Out:
#          Codice       Data Piezometria (m) Soggiacenza (m)
# 0       BO05-00 2020-02-24           17.38            4.81
# 1       BO05-00 2020-12-10           14.79             7.4
# 3       BO08-00 2020-10-28           24.45             0.8
# 4       BO11-01 2020-06-04            37.4             6.6
# 5       BO11-01 2020-10-07           35.73            8.27
# ...         ...        ...             ...             ...
# 2833  RN-F03-00 2011-02-16             3.4             0.6
# 2834  RN-F03-00 2011-04-06             3.4             0.6
# 2835  RN-F03-00 2011-10-12            1.02            2.98
# 2836  RN-F03-00 2012-04-04            -0.4             4.4
# 2837  RN-F03-00 2012-10-15           -0.35            4.35
#
# [10161 rows x 4 columns]

# %%
date_arr = []
for i in whole_table['Data']:
    date_arr = np.append(date_arr, (str(i)[:10]))
    
whole_table['Data'] = date_arr

# %%
directory_name = '/EmiliaRomagna'

if not (os.path.exists(cwd + "/processed_data/"+ directory_name + "_processed")): 
            os.makedirs(cwd + "/processed_data/"+ directory_name + "_processed")

df = pd.read_excel(xls, 'Anagrafica')
# df['Latitude'] = utm.to_latlon(df['X_UTM-ED50'], df['Y_UTM-ED50'], 32, 'T')[0]
# df['Longitude'] = utm.to_latlon(df['X_UTM-ED50'], df['Y_UTM-ED50'], 32, 'T')[1]
# df = df.drop(['X_UTM-ED50', 'Y_UTM-ED50'], axis = 1)
# df
# df.to_excel(cwd + "/processed_data" + directory_name + "_processed/STATIC_EMILIAROMAGNA_TABLE.xlsx", index = False)

# %%
        
whole_table.to_excel(cwd + "/processed_data" + directory_name + "_processed/COMBINED_EMILIAROMAGNA_TABLE.xlsx", index = False)

# %%
hold
# Out:
#     Provincia Codice_RER Tipologia stazione                     Comune  \
# 0          BO    BO03-01              Pozzo       SAN PIETRO IN CASALE
# 1          BO    BO04-01              Pozzo                 MALALBERGO
# 2          BO    BO05-00              Pozzo       SANT AGATA BOLOGNESE
# 3          BO    BO06-00              Pozzo  SAN GIOVANNI IN PERSICETO
# 4          BO    BO07-00              Pozzo             SALA BOLOGNESE
# ..        ...        ...                ...                        ...
# 673        RN  RN-M01-00           Sorgente                CASTELDELCI
# 674        RN  RN-M03-00           Sorgente                 PENNABILLI
# 675        RN  RN-M06-00           Sorgente                    SAN LEO
# 676        RN  RN-M11-00              Pozzo                NOVAFELTRIA
# 677        RN  RN-M12-00           Sorgente         SANT'AGATA FELTRIA
#
#            Localita  X_UTM-ED50  Y_UTM-ED50  Quota_PC  profondita  \
# ...

# %%
hold = df.head(1)
inProj = Proj(init='epsg:5659');
outProj = Proj(init='epsg:4326');
x1,y1 = hold['X_UTM-ED50'], hold['Y_UTM-ED50'];
x2,y2 = transform(inProj,outProj,x1,y1);
hold['Latitude'] = x2;
hold['Longitude'] = y2;
# Out:
# /Users/andrew/opt/anaconda3/lib/python3.9/site-packages/pyproj/crs/crs.py:130: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/andrew/opt/anaconda3/lib/python3.9/site-packages/pyproj/crs/crs.py:130: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# ...

# %%
hold = hold.drop(['X_UTM-ED50', 'Y_UTM-ED50'], axis = 1)

# %%
hold.to_excel(cwd + "/processed_data" + directory_name + "_processed/STATIC_EMILIAROMAGNA_TABLE.xlsx", index = False)

# %%
for i in df['Codice_RER']:
    hold = df
    inProj = Proj(init='epsg:5659');
    outProj = Proj(init='epsg:4326');
    x1,y1 = hold['X_UTM-ED50'], hold['Y_UTM-ED50'];
    x2,y2 = transform(inProj,outProj,x1,y1);
    hold['Longitude'] = x2;
    hold['Latitude'] = y2;
# Out:
# /Users/andrew/opt/anaconda3/lib/python3.9/site-packages/pyproj/crs/crs.py:130: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/andrew/opt/anaconda3/lib/python3.9/site-packages/pyproj/crs/crs.py:130: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# ...

# %%
if not (os.path.exists(cwd + "/processed_data/"+ directory_name + "_processed")): 
            os.makedirs(cwd + "/processed_data/"+ directory_name + "_processed")
        
for i in whole_table['Codice'].unique():
    hold = whole_table[whole_table['Codice'] == i]
    max_year = str(hold[hold['Codice'] == i]['Data'].max())[:4]
    min_year = str(hold[hold['Codice'] == i]['Data'].min())[:4]
    
    hold = hold.sort_values(by = ['Data'], ascending = False)

    if len(hold) > 10:
        hold.to_excel(cwd + "/processed_data" + directory_name + "_processed/" + i + "_" + min_year + "_" + max_year + '.xlsx',
                      index = False)
        if not (os.path.exists(cwd + "/processed_data" + directory_name + "_processed/mat_files/")): 
                os.makedirs(cwd + "/processed_data" + directory_name + "_processed/mat_files/")
        savemat(cwd + "/processed_data" + directory_name + "_processed/mat_files/" + str(i) + "_" +
                min_year + "_" + 
                max_year + ".mat", hold)
